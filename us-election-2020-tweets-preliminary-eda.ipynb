# %% [markdown]
# Greetings! In this starter kernel we will perform some very light exploratory analysis, first we will import the required libraries to load data (pandas) and seaborn which will need to plot some of the data. There are two .csv files in this dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/us-election-2020-tweets/hashtag_joebiden.csv
# /kaggle/input/us-election-2020-tweets/hashtag_donaldtrump.csv

# %% [markdown]
# ### Let's check 1st file: /kaggle/input/us-election-2020-tweets/hashtag_donaldtrump.csv

# %%
df1=pd.read_csv('/kaggle/input/us-election-2020-tweets/hashtag_donaldtrump.csv', lineterminator='\n')
df1.head(2).T
# Out:
#                                                                       0  \
# created_at                                          2020-10-15 00:00:01
# tweet_id                                                    1.31653e+18
# tweet                 #Elecciones2020 | En #Florida: #JoeBiden dice ...
# likes                                                                 0
# retweet_count                                                         0
# source                                                        TweetDeck
# user_id                                                     3.60667e+08
# user_name                                            El Sol Latino News
# user_screen_name                                        elsollatinonews
# user_description      🌐 Noticias de interés para latinos de la costa...
# user_join_date                                      2011-08-23 15:33:45
# user_followers_count                                               1860
# ...

# %% [markdown]
# ### Basic Statistical Details

# %%
df1.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  5.367260e+05  536726.000000  536726.000000  5.367260e+05
# mean   1.320679e+18       5.162103       1.502202  4.482647e+17
# std    2.154900e+15     114.855410      34.553388  5.534836e+17
# min    1.316529e+18       0.000000       0.000000  5.310000e+02
# 25%    1.318987e+18       0.000000       0.000000  2.020879e+08
# 50%    1.320834e+18       0.000000       0.000000  2.373952e+09
# 75%    1.322914e+18       1.000000       0.000000  1.076183e+18
# max    1.323777e+18   26039.000000   12181.000000  1.323772e+18
#
#        user_followers_count            lat           long
# count          5.367260e+05  263746.000000  263746.000000
# mean           1.719070e+04      36.517601     -53.357476
# std            2.473937e+05      16.596324      64.536839
# min            0.000000e+00     -90.000000    -175.202642
# 25%            7.800000e+01      33.749099    -100.445882
# ...

# %% [markdown]
# ### Numeric Columns Visualised

# %%
g=sns.pairplot(df1, vars=['tweet_id','likes','retweet_count','user_id','user_followers_count','lat','long'], 
               plot_kws = {'alpha': 0.6, 's': 30, 'edgecolor': 'black'}, height=1.5, dropna=True)
g.map_upper(sns.scatterplot, color='red')
g.map_lower(sns.scatterplot, color='red')
g.map_diag(plt.hist, color='red')

# %%
df1.isnull().sum()
# Out:
# created_at                   0
# tweet_id                     0
# tweet                        0
# likes                        0
# retweet_count                0
# source                     651
# user_id                      0
# user_name                   13
# user_screen_name             0
# user_description         56986
# user_join_date               0
# user_followers_count         0
# user_location           166121
# lat                     272980
# long                    272980
# city                    407688
# country                 274539
# continent               274528
# state                   340765
# state_code              349765
# collected_at                 0
# dtype: int64

# %% [markdown]
# Significant number of NA values found in the geolocation data columns.

# %% [markdown]
# ### Let's check 2nd file: /kaggle/input/us-election-2020-tweets/hashtag_joebiden.csv

# %%
df2=pd.read_csv('/kaggle/input/us-election-2020-tweets/hashtag_joebiden.csv', lineterminator='\n')
df2.head(2).T
# Out:
#                                                                       0  \
# created_at                                          2020-10-15 00:00:01
# tweet_id                                                    1.31653e+18
# tweet                 #Elecciones2020 | En #Florida: #JoeBiden dice ...
# likes                                                                 0
# retweet_count                                                         0
# source                                                        TweetDeck
# user_id                                                     3.60667e+08
# user_name                                            El Sol Latino News
# user_screen_name                                        elsollatinonews
# user_description      🌐 Noticias de interés para latinos de la costa...
# user_join_date                                      2011-08-23 15:33:45
# user_followers_count                                               1860
# ...

# %% [markdown]
# ### Basic Statistical Details

# %%
df2.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  3.606330e+05  360633.000000   360633.00000  3.606330e+05
# mean   1.320550e+18       8.707487        2.51828  4.505910e+17
# std    2.176336e+15     515.966119      130.16765  5.573924e+17
# min    1.316529e+18       0.000000        0.00000  2.654000e+03
# 25%    1.319014e+18       0.000000        0.00000  2.079504e+08
# 50%    1.320429e+18       0.000000        0.00000  2.426372e+09
# 75%    1.322628e+18       1.000000        0.00000  1.089217e+18
# max    1.323777e+18  165702.000000    63473.00000  1.323766e+18
#
#        user_followers_count            lat           long
# count          3.606330e+05  175327.000000  175327.000000
# mean           1.971631e+04      36.548121     -61.147377
# std            3.794654e+05      15.195319      60.494512
# min            0.000000e+00     -79.406307    -161.755833
# 25%            7.600000e+01      33.750038    -100.445882
# ...

# %% [markdown]
# Numeric Columns Visualised

# %%
sns.pairplot(df2, vars=['tweet_id','likes','retweet_count','user_id','user_followers_count','lat','long'], 
             plot_kws = {'alpha': 0.6, 's': 30, 'edgecolor': 'k'}, height=1.5, dropna=True)

# %%
df2.isnull().sum()
# Out:
# created_at                   0
# tweet_id                     0
# tweet                        0
# likes                        0
# retweet_count                0
# source                     538
# user_id                      0
# user_name                   16
# user_screen_name             0
# user_description         42799
# user_join_date               0
# user_followers_count         0
# user_location           116744
# lat                     185306
# long                    185306
# city                    274669
# country                 185952
# continent               185944
# state                   226480
# state_code              231701
# collected_at                 0
# dtype: int64

# %% [markdown]
# Significant number of NA values found in the geolocation data columns.

# %% [markdown]
# ### End of Starter Kernel
