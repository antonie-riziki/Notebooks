# %% [markdown]
# ### Regression
# #### On this Dataset, we will focus on Regression Analysis [Predictive Modelling]
# #### Predicting the Relationship between dependent [Target] and independent [Predictor]

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
train = pd.read_csv(r"D:\Open Classroom\Data Files\Big Mart Sales Prediction\train.csv")
test = pd.read_csv(r"D:\Open Classroom\Data Files\Big Mart Sales Prediction\test.csv")


print(f"Shape of Training Data {train.shape}")
print(f"Shape of Test Data {test.shape}")

X = train.drop(columns = ["Item_Outlet_Sales"], axis = 1)
y = train["Item_Outlet_Sales"]

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = LinearRegression()

#Fit the model with the training data
model.fit(X_train, y_train)

#Coefficients of the Trained Model
print("\n\nModel Coefficients: \n", model.coef_)

#Interception of the MOdel
print("\n\nIntercept Model: ", model.intercept_)

#Predict the Target on the test dataset
predict = model.predict(X_train)
print("\n\nModel Prediction: \n", predict)

#Root Mean Squared Error
rmse_train = mean_squared_error(y_train, predict)*0.05
print("\n\nTrain Mean Error: ", rmse_train)
# Out:
# Shape of Training Data (1364, 36)
# Shape of Test Data (341, 36)
#
#
# Model Coefficients:
#  [-1.09335116e+01  1.47048652e+02  1.62623047e+01  7.35027294e+01
#  -7.48496929e+01  1.30754130e+02  3.14410567e+02 -1.39417447e+02
#  -2.30897556e+02 -2.65724248e+01 -1.52231493e+02  1.38529283e+02
#  -6.94899174e+01  8.13479492e+01 -1.28785806e+00 -8.87544819e+00
#   4.18622596e+02 -5.33537210e+01  1.88052360e+01 -8.75529511e+01
#   1.12133540e+02 -2.24402115e+02  9.49968058e+01  5.84474467e+01
#  -2.99116929e+02  1.84566618e+03  2.68423595e+02  1.24547810e+02
#   4.21889577e+02  1.87857452e+01 -4.40675323e+02 -1.32770413e+03
#  -4.05038679e+02 -1.05076324e+03  2.78350604e+03]
#
#
# Intercept Model:  -147005.44181113114
#
#
# Model Prediction:
#  [2479.85025679 1825.49765994 1302.01504338 ... 1329.0161062  2484.41364483
#  3095.58966043]
#
#
# Train Mean Error:  61445.010613235936

# %%
train = pd.read_csv(r"D:\Open Classroom\Data Files\Big Mart Sales Prediction\train.csv")
test = pd.read_csv(r"D:\Open Classroom\Data Files\Big Mart Sales Prediction\test.csv")

x_train = train.drop(columns = ["Item_Outlet_Sales"], axis = 1)
y_train = train["Item_Outlet_Sales"]

x_test = test.drop(columns = ["Item_Outlet_Sales"], axis = 1)
y_test = test["Item_Outlet_Sales"]

model = LinearRegression()

model.fit(x_train, y_train)

print("\n\n Model Coefficient: \n", model.coef_)

print("\n\n Model Interception: ", model.intercept_)

train_predictor = model.predict(x_train)
print("\n\n Predict the Train Model: \n\n", train_predictor)

test_predictor = model.predict(x_test)
print("\n\n Predict the Test Model: \n\n", test_predictor.any())

#Root Mean Squared Error
rmse_train = mean_squared_error(y_train, train_predictor) * 0.5
print("\n\n Root Mean Squared Error Train Model: ", rmse_train)

rmse_test = mean_squared_error(y_test, test_predictor) * 0.5
print("\n\n Root Mean Squared Error Test Model: ", rmse_test)
# Out:
#  Model Coefficient:
#  [-3.84197604e+00  9.83065945e+00  1.61711856e+01  6.09197622e+01
#  -8.64161561e+01  1.23593376e+02  2.34714039e+02 -2.44597425e+02
#  -2.72938329e+01 -8.09611456e+00 -3.01147840e+02  1.70727611e+02
#  -5.40194744e+01  7.34248834e+01  1.70313375e+00 -5.07701615e+01
#   1.63553657e+02 -5.85286125e+01  1.04913492e+02 -6.01944874e+01
#   1.98948206e+02 -1.40959023e+02  1.19426257e+02  2.66382669e+01
#  -1.85619792e+02  1.43925357e+03  2.16134663e+02  3.54723990e+01
#   3.54832996e+02 -5.54559635e+00 -3.49287400e+02 -1.39202954e+03
#  -2.57982359e+02 -9.59016062e+02  2.60902796e+03]
#
#
#  Model Interception:  -121926.97473298296
#
#
#  Predict the Train Model:
#
#  [ 803.88817641 1733.98835979 3294.52154482 ...  811.16967914 2343.96927185
#  2444.98869913]
#
#
#  Predict the Test Model:
#
#  True
#
#
#  Root Mean Squared Error Train Model:  645038.9184361054
#
#
#  Root Mean Squared Error Test Model:  509294.5204122472

# %%
'''
The following code is for the Linear Regression
Created by- ANALYTICS VIDHYA
'''

# importing required libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# reading the train and test dataset
train_data = pd.read_csv(r"D:\Open Classroom\Data Files\Big Mart Sales Prediction\train.csv")
test_data = pd.read_csv(r"D:\Open Classroom\Data Files\Big Mart Sales Prediction\test.csv")

# shape of the dataset
print('\nShape of training data :',train_data.shape)
print('\nShape of testing data :',test_data.shape)

# Now, we need to predict the target variable in the test data
# target variable - Item_Outlet_Sales

# seperate the independent and target variable on training data
train_x = train_data.drop(columns=['Item_Outlet_Sales'],axis=1)
train_y = train_data['Item_Outlet_Sales']

# seperate the independent and target variable on training data
test_x = test_data.drop(columns=['Item_Outlet_Sales'],axis=1)
test_y = test_data['Item_Outlet_Sales']

'''
Create the object of the Linear Regression model
You can also add other parameters and test your code here
Some parameters are : fit_intercept and normalize
Documentation of sklearn LinearRegression: 

https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

 '''
model = LinearRegression()

# fit the model with the training data
model.fit(train_x,train_y)

# coefficeints of the trained model
print('\nCoefficient of model :', model.coef_)

# intercept of the model
print('\nIntercept of model',model.intercept_)

# predict the target on the test dataset
predict_train = model.predict(train_x)

# Root Mean Squared Error on training dataset
rmse_train = mean_squared_error(train_y,predict_train)**(0.5)
print('\nRMSE on train dataset : ', rmse_train)

# predict the target on the testing dataset
predict_test = model.predict(test_x) 

# Root Mean Squared Error on testing dataset
rmse_test = mean_squared_error(test_y,predict_test)**(0.5)
print('\nRMSE on test dataset : ', rmse_test)
# Out:
# Shape of training data : (1364, 36)
#
# Shape of testing data : (341, 36)
#
# Coefficient of model : [-3.84197604e+00  9.83065945e+00  1.61711856e+01  6.09197622e+01
#  -8.64161561e+01  1.23593376e+02  2.34714039e+02 -2.44597425e+02
#  -2.72938329e+01 -8.09611456e+00 -3.01147840e+02  1.70727611e+02
#  -5.40194744e+01  7.34248834e+01  1.70313375e+00 -5.07701615e+01
#   1.63553657e+02 -5.85286125e+01  1.04913492e+02 -6.01944874e+01
#   1.98948206e+02 -1.40959023e+02  1.19426257e+02  2.66382669e+01
#  -1.85619792e+02  1.43925357e+03  2.16134663e+02  3.54723990e+01
#   3.54832996e+02 -5.54559635e+00 -3.49287400e+02 -1.39202954e+03
#  -2.57982359e+02 -9.59016062e+02  2.60902796e+03]
#
# Intercept of model -121926.97473298296
#
# RMSE on train dataset :  1135.8159344155245
#
# RMSE on test dataset :  1009.2517232209685
