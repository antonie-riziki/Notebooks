# %% [markdown]
# # Weight Loss

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import autoreload
import missingno as msno
import warnings
import csv
import os
import sys

from collections import defaultdict, Counter

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVR, SVR 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error 

# %matplotlib inline
plt.rcParams.update({'font.size':16})

sb.set_style('darkgrid')
sb.set()

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)
# Out:
# Requirement already satisfied: numpy in d:\team software\anaconda3\lib\site-packages (1.16.5)

# %%
df = pd.read_csv("D:\Open Classroom\Datasets\Steps Count for Fitness Journey Dataset\Steps Export_ 3-17-21to9-23-22.csv")
df.head()
# Out:
#         Date  Step Count Distance Travelled Active Time  Flights Climbed  \
# 0  3/17/2021        1500            1.02 km   23:14 min                3
# 1  3/18/2021        3165            2.23 km   44:56 min                2
# 2  3/19/2021        1494            1.08 km   24:51 min                0
# 3  3/20/2021        1808            1.27 km   30:04 min                1
# 4  3/21/2021        2667            1.78 km   30:57 min                3
#
#     Goal Percentage of Goal Completed  Calories
# 0  10000                          15%        64
# 1  10000                          32%       134
# 2  10000                          15%        68
# 3  10000                          18%        81
# 4  10000                          27%       103

# %%
df.shape
# Out:
# (526, 8)

# %%
df.isnull().sum()
# Out:
# Date                            0
# Step Count                      0
# Distance Travelled              0
# Active Time                     0
# Flights Climbed                 0
# Goal                            0
# Percentage of Goal Completed    0
# Calories                        0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['unit'] = df['Distance Travelled'].str.split(' ', expand = True).get(1)

# %%
df.head()
# Out:
#         Date  Step Count Distance Travelled Active Time  Flights Climbed  \
# 0 2021-03-17        1500            1.02 km   23:14 min                3
# 1 2021-03-18        3165            2.23 km   44:56 min                2
# 2 2021-03-19        1494            1.08 km   24:51 min                0
# 3 2021-03-20        1808            1.27 km   30:04 min                1
# 4 2021-03-21        2667            1.78 km   30:57 min                3
#
#     Goal Percentage of Goal Completed  Calories unit
# 0  10000                          15%        64   km
# 1  10000                          32%       134   km
# 2  10000                          15%        68   km
# 3  10000                          18%        81   km
# 4  10000                          27%       103   km

# %%
df['Percentage of Goal Completed'] = (df['Step Count'] * 100) /df['Goal']

# %%
df.head()
# Out:
#         Date  Step Count Distance Travelled Active Time  Flights Climbed  \
# 0 2021-03-17        1500            1.02 km   23:14 min                3
# 1 2021-03-18        3165            2.23 km   44:56 min                2
# 2 2021-03-19        1494            1.08 km   24:51 min                0
# 3 2021-03-20        1808            1.27 km   30:04 min                1
# 4 2021-03-21        2667            1.78 km   30:57 min                3
#
#     Goal  Percentage of Goal Completed  Calories unit
# 0  10000                         15.00        64   km
# 1  10000                         31.65       134   km
# 2  10000                         14.94        68   km
# 3  10000                         18.08        81   km
# 4  10000                         26.67       103   km

# %%
df['Distance Travelled'] = df['Distance Travelled'].str.replace('km', '')

# %%
df.head()
# Out:
#         Date  Step Count Distance Travelled Active Time  Flights Climbed  \
# 0 2021-03-17        1500              1.02    23:14 min                3
# 1 2021-03-18        3165              2.23    44:56 min                2
# 2 2021-03-19        1494              1.08    24:51 min                0
# 3 2021-03-20        1808              1.27    30:04 min                1
# 4 2021-03-21        2667              1.78    30:57 min                3
#
#     Goal  Percentage of Goal Completed  Calories unit
# 0  10000                         15.00        64   km
# 1  10000                         31.65       134   km
# 2  10000                         14.94        68   km
# 3  10000                         18.08        81   km
# 4  10000                         26.67       103   km

# %%
df['Distance Travelled'] = pd.to_numeric(df['Distance Travelled'])

# %%
df['Distance Travelled'].dtypes
# Out:
# dtype('float64')

# %%
df['Goal'].dtypes
# Out:
# dtype('int64')

# %%
df['Percentage of Goal Completed'].dtypes
# Out:
# dtype('float64')

# %%
df[['Active Time', 'Time units']] = df['Active Time'].str.split(' ', expand=True)#.get(1)
df.head()
# Out:
#         Date  Step Count  Distance Travelled Active Time  Flights Climbed  \
# 0 2021-03-17        1500                1.02       23:14                3
# 1 2021-03-18        3165                2.23       44:56                2
# 2 2021-03-19        1494                1.08       24:51                0
# 3 2021-03-20        1808                1.27       30:04                1
# 4 2021-03-21        2667                1.78       30:57                3
#
#     Goal  Percentage of Goal Completed  Calories unit Time units
# 0  10000                         15.00        64   km        min
# 1  10000                         31.65       134   km        min
# 2  10000                         14.94        68   km        min
# 3  10000                         18.08        81   km        min
# 4  10000                         26.67       103   km        min

# %%
df['Active Time'] = df['Active Time'].str.replace(':', '.')
df['Active Time'] = pd.to_numeric(df['Active Time'])

# %%
df['Active Time'].dtypes
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#         Date  Step Count  Distance Travelled  Active Time  Flights Climbed  \
# 0 2021-03-17        1500                1.02        23.14                3
# 1 2021-03-18        3165                2.23        44.56                2
# 2 2021-03-19        1494                1.08        24.51                0
# 3 2021-03-20        1808                1.27        30.04                1
# 4 2021-03-21        2667                1.78        30.57                3
#
#     Goal  Percentage of Goal Completed  Calories unit Time units
# 0  10000                         15.00        64   km        min
# 1  10000                         31.65       134   km        min
# 2  10000                         14.94        68   km        min
# 3  10000                         18.08        81   km        min
# 4  10000                         26.67       103   km        min

# %%
df['Active Time'].dtypes
# Out:
# dtype('float64')

# %%
# df['Active Time in Mins'] = np.where(df['Active Time'] * 60, df['Time units'] == 'hr')
# def create_minutes(data['Active Time']):
for i in df['Active Time']:
    if any(df['Time units'] == 'hr'):
        df['Active time in mins'] = df['Active Time'] * 60
    elif any(df['Time units'] == 'min'):
        df['Active time in mins'] = df['Active Time']

# %%
df.head(30)
# Out:
#          Date  Step Count  Distance Travelled  Active Time  Flights Climbed  \
# 0  2021-03-17        1500                1.02        23.14                3
# 1  2021-03-18        3165                2.23        44.56                2
# 2  2021-03-19        1494                1.08        24.51                0
# 3  2021-03-20        1808                1.27        30.04                1
# 4  2021-03-21        2667                1.78        30.57                3
# 5  2021-03-22        2368                1.69        37.25                1
# 6  2021-03-23        3595                2.68        54.10                2
# 7  2021-03-24         779                0.58        13.08                2
# 8  2021-03-25        2566                1.87        38.38                1
# 9  2021-03-26        1687                1.24        25.42                1
# 10 2021-03-27        1294                0.94        20.23                0
# 11 2021-03-28        2173                1.52        32.33                2
# 12 2021-03-29        1696                1.24        26.52                2
# 13 2021-03-30        3892                2.87        51.14                0
# 14 2021-03-31        1271                0.93        17.07                0
# 15 2021-04-01        3405                2.27        48.48                0
# 16 2021-04-02        2458                1.79        40.38                0
# 17 2021-04-03        2568                1.78        41.51                1
# 18 2021-04-04        3216                2.23        51.26                2
# 19 2021-04-05        2582                1.82        43.01                0
# 20 2021-04-06        4210                3.04         1.05                4
# 21 2021-04-07        6475                4.79         1.16                1
# 22 2021-04-08        5771                4.21         1.26                3
# 23 2021-04-09        1163                0.83        19.16                0
# 24 2021-04-10         634                0.44        10.22                0
# 25 2021-04-11        1361                0.96        22.35                3
# 26 2021-04-12        6515                4.80         1.21                0
# 27 2021-04-13       12201                8.97         2.36                2
# 28 2021-04-14       11669                8.62         2.18                1
# 29 2021-04-15        4259                3.11         1.06                2
#
#      Goal  Percentage of Goal Completed  Calories unit Time units  \
# 0   10000                         15.00        64   km        min
# 1   10000                         31.65       134   km        min
# 2   10000                         14.94        68   km        min
# 3   10000                         18.08        81   km        min
# 4   10000                         26.67       103   km        min
# 5   10000                         23.68       105   km        min
# 6   10000                         35.95       161   km        min
# 7   10000                          7.79        36   km        min
# 8   10000                         25.66       113   km        min
# 9   10000                         16.87        75   km        min
# 10  10000                         12.94        58   km        min
# 11  10000                         21.73        93   km        min
# 12  10000                         16.96        76   km        min
# 13  10000                         38.92       168   km        min
# 14  10000                         12.71        54   km        min
# 15  10000                         34.05       139   km        min
# 16  10000                         24.58       112   km        min
# 17  10000                         25.68       113   km        min
# 18  10000                         32.16       140   km        min
# 19  10000                         25.82       116   km        min
# 20  10000                         42.10       187   km         hr
# 21  10000                         64.75       276   km         hr
# 22  10000                         57.71       254   km         hr
# 23  10000                         11.63        53   km        min
# 24  10000                          6.34        28   km        min
# 25  10000                         13.61        61   km        min
# 26  10000                         65.15       278   km         hr
# 27  10000                        122.01       521   km         hr
# 28  10000                        116.69       498   km         hr
# 29  10000                         42.59       190   km         hr
#
#     Active time in mins
# 0                1388.4
# 1                2673.6
# 2                1470.6
# 3                1802.4
# 4                1834.2
# 5                2235.0
# 6                3246.0
# 7                 784.8
# 8                2302.8
# 9                1525.2
# 10               1213.8
# 11               1939.8
# 12               1591.2
# 13               3068.4
# 14               1024.2
# 15               2908.8
# 16               2422.8
# 17               2490.6
# 18               3075.6
# 19               2580.6
# 20                 63.0
# 21                 69.6
# 22                 75.6
# 23               1149.6
# 24                613.2
# 25               1341.0
# 26                 72.6
# 27                141.6
# 28                130.8
# 29                 63.6

# %%
#df['Active Time'] = df['Active Time'].str.replace(' hr', '*60')

# %%
#df['Active Time'] = df['Active Time'].str.replace(':','.')

# %%
#df['Active Time'] = df['Active Time'].str.replace('min', '')

# %%
#df['Active Time'] = df['Active Time'].astype(float)

# %%
df.head(30)
# Out:
#          Date  Step Count  Distance Travelled  Active Time  Flights Climbed  \
# 0  2021-03-17        1500                1.02        23.14                3
# 1  2021-03-18        3165                2.23        44.56                2
# 2  2021-03-19        1494                1.08        24.51                0
# 3  2021-03-20        1808                1.27        30.04                1
# 4  2021-03-21        2667                1.78        30.57                3
# 5  2021-03-22        2368                1.69        37.25                1
# 6  2021-03-23        3595                2.68        54.10                2
# 7  2021-03-24         779                0.58        13.08                2
# 8  2021-03-25        2566                1.87        38.38                1
# 9  2021-03-26        1687                1.24        25.42                1
# 10 2021-03-27        1294                0.94        20.23                0
# 11 2021-03-28        2173                1.52        32.33                2
# 12 2021-03-29        1696                1.24        26.52                2
# 13 2021-03-30        3892                2.87        51.14                0
# 14 2021-03-31        1271                0.93        17.07                0
# 15 2021-04-01        3405                2.27        48.48                0
# 16 2021-04-02        2458                1.79        40.38                0
# 17 2021-04-03        2568                1.78        41.51                1
# 18 2021-04-04        3216                2.23        51.26                2
# 19 2021-04-05        2582                1.82        43.01                0
# 20 2021-04-06        4210                3.04         1.05                4
# 21 2021-04-07        6475                4.79         1.16                1
# 22 2021-04-08        5771                4.21         1.26                3
# 23 2021-04-09        1163                0.83        19.16                0
# 24 2021-04-10         634                0.44        10.22                0
# 25 2021-04-11        1361                0.96        22.35                3
# 26 2021-04-12        6515                4.80         1.21                0
# 27 2021-04-13       12201                8.97         2.36                2
# 28 2021-04-14       11669                8.62         2.18                1
# 29 2021-04-15        4259                3.11         1.06                2
#
#      Goal  Percentage of Goal Completed  Calories unit Time units  \
# 0   10000                         15.00        64   km        min
# 1   10000                         31.65       134   km        min
# 2   10000                         14.94        68   km        min
# 3   10000                         18.08        81   km        min
# 4   10000                         26.67       103   km        min
# 5   10000                         23.68       105   km        min
# 6   10000                         35.95       161   km        min
# 7   10000                          7.79        36   km        min
# 8   10000                         25.66       113   km        min
# 9   10000                         16.87        75   km        min
# 10  10000                         12.94        58   km        min
# 11  10000                         21.73        93   km        min
# 12  10000                         16.96        76   km        min
# 13  10000                         38.92       168   km        min
# 14  10000                         12.71        54   km        min
# 15  10000                         34.05       139   km        min
# 16  10000                         24.58       112   km        min
# 17  10000                         25.68       113   km        min
# 18  10000                         32.16       140   km        min
# 19  10000                         25.82       116   km        min
# 20  10000                         42.10       187   km         hr
# 21  10000                         64.75       276   km         hr
# 22  10000                         57.71       254   km         hr
# 23  10000                         11.63        53   km        min
# 24  10000                          6.34        28   km        min
# 25  10000                         13.61        61   km        min
# 26  10000                         65.15       278   km         hr
# 27  10000                        122.01       521   km         hr
# 28  10000                        116.69       498   km         hr
# 29  10000                         42.59       190   km         hr
#
#     Active time in mins
# 0                1388.4
# 1                2673.6
# 2                1470.6
# 3                1802.4
# 4                1834.2
# 5                2235.0
# 6                3246.0
# 7                 784.8
# 8                2302.8
# 9                1525.2
# 10               1213.8
# 11               1939.8
# 12               1591.2
# 13               3068.4
# 14               1024.2
# 15               2908.8
# 16               2422.8
# 17               2490.6
# 18               3075.6
# 19               2580.6
# 20                 63.0
# 21                 69.6
# 22                 75.6
# 23               1149.6
# 24                613.2
# 25               1341.0
# 26                 72.6
# 27                141.6
# 28                130.8
# 29                 63.6
