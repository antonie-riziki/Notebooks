# %% [markdown]
# # **World Health 2020 🌏**
#
# These <span style="color:blue">39 datasets</span> cover the most recent and updated health statistics of the world (countries recognized by WHO- all). They are divided into different subcategories. In order to capture the theme of <span style="color:red">World vs India</span>, I have tried to visualise the data by generalising the plots into 2 main category -
# 1. World demographics on a timeline
# 1. World vs India trend
#
# For certain cases where there was no data available for India, the trend is plotted for the world only.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
import glob
import os

warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Load all the files together**

# %%
for data_file in glob.glob('../input/who-worldhealth-statistics-2020-complete/*'):
    df_name = 'df_' + os.path.basename(data_file).split('.')[0]
    globals()[df_name] = pd.read_csv(data_file)

# %% [markdown]
# ## **Helper functions for Plotting**

# %%
def plot_worldmap(df, location, time, color, title):
    fig = px.choropleth(df, 
                        locations=location,
                        locationmode = "country names",
                        color=color, 
                        hover_name=location, 
                        animation_frame=time
                       )
    fig.update_layout(title_text = title,
                      title_x = 0.5,
                      geo=dict(
                      showframe = False,
                      showcoastlines = False)
                    )
    fig.show()

# %%
def plot_world_vs_india(df, x, y, color_row, facet_row, title):
    fig = px.line(df, x=x, y=y, color= color_row, facet_row=facet_row)
    fig.update_layout(title_text = title, title_x = 0.5)
    fig.show()

# %% [markdown]
# # **Life Expectancy and Healthy Life Expectancy**

# %% [markdown]
# ## **Life Expectancy at Birth (years)**

# %%
df_lifeExpectancyAtBirth = df_lifeExpectancyAtBirth[df_lifeExpectancyAtBirth['Period'] > 1920]
df_world = df_lifeExpectancyAtBirth[df_lifeExpectancyAtBirth['Dim1'] == 'Both sexes'].sort_values(by=['Period']).reset_index()
df_india = df_lifeExpectancyAtBirth[df_lifeExpectancyAtBirth['Location'] == 'India'].reset_index(drop=True)
df_restworld = df_lifeExpectancyAtBirth[df_lifeExpectancyAtBirth['Location'] != 'India'].reset_index(drop=True)
df_restworld = df_restworld.groupby(['Period', 'Dim1'])['First Tooltip'].mean().reset_index()
df_restworld['Location'] = 'Rest of the World'
df_world_vs_india = df_india.append(df_restworld).reset_index(drop=True)

# %%
df_world.rename(columns={'First Tooltip': 'Life Expectancy'}, inplace=True)
plot_worldmap(df_world, 'Location', 'Period', 'Life Expectancy', 'Life Expectancy at Birth (years)')
df_world_vs_india.rename(columns={'Dim1': 'Sex', 'First Tooltip': 'Life Expectancy'}, inplace=True)
plot_world_vs_india(df_world_vs_india, 'Period', 'Life Expectancy', 'Sex', 'Location', 'Life Expectancy at Birth (years)')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="8d148020-08d7-4b77-8bee-ce95e92f01d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d148020-08d7-4b77-8bee-ce95e92f01d3")) {                    Plotly.newPlot(                        "8d148020-08d7-4b77-8bee-ce95e92f01d3",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>Period=2000<br>Location=%{location}<br>Life Expectancy=%{z}<extra></extra>", "hovertext": ["Zimbabwe", "Singapore", "Eritrea", "Montenegro", "Sierra Leone", "Eswatini", "Seychelles", "Ethiopia", "Fiji", "Serbia", "Finland", "Senegal", "France", "Gabon", "Equatorial Guinea", "Saudi Arabia", "Sao Tome and Principe", "Georgia", "Germany", "Samoa", "Ghana", "Saint Vincent and the Grenadines", "Greece", "Grenada", "Saint Lucia", "Guatemala", "Rwanda", "Guinea", "Guinea-Bissau", "Gambia", "Slovakia", "El Salvador", "Egypt", "Chile", "Syrian Arab Republic", "China", "Switzerland", "Colombia", "Comoros", "Sweden", "Congo", "Suriname", "Costa Rica", "C\u00f4te d\u2019Ivoire", "Sudan (until 2011)", "Croatia", "Sri Lanka", "Cuba", "Cyprus", "Spain", "Czechia", "South Sudan", "Democratic People's Republic of Korea", "Democratic Republic of the Congo", "South Africa", "Denmark", "Somalia", "Djibouti", "Dominican Republic", "Solomon Islands", "Ecuador", "Slovenia", "Russian Federation", "Chad", "Guyana", "Haiti", "Lebanon", "Norway", "Lesotho", "Nigeria", "Liberia", "Libya", "Niger", "Lithuania", "Nicaragua", "Luxembourg", "Madagascar", "New Zealand", "Malawi", "Latvia", "Netherlands", "Maldives", "Nepal", "Mali", "Namibia", "Malta", "Mauritania", "Myanmar", "Mauritius", "Mozambique", "Mexico", "Micronesia (Federated States of)", "Morocco", "Mongolia", "Malaysia", "Oman", "Lao People's Democratic Republic", "Kyrgyzstan", "Honduras", "The former Yugoslav Republic of Macedonia", "Hungary", "Republic of Moldova", "Iceland", "India", "Republic of Korea", "Indonesia", "Qatar", "Iran (Islamic Republic of)", "Iraq", "Portugal", "Ireland", "Poland", "Israel", "Italy", "Philippines", "Jamaica", "Peru", "Japan", "Jordan", "Paraguay", "Kazakhstan", "Papua New Guinea", "Kenya", "Kiribati", "Panama", "Kuwait", "Pakistan", "Romania", "Tajikistan", "Estonia", "Brazil", "Vanuatu", "Uganda", "Angola", "Viet Nam", "Uzbekistan", "Barbados", "Togo", "United States of America", "Cabo Verde", "Australia", "Antigua and Barbuda", "Uruguay", "Venezuela (Bolivarian Republic of)", "Bolivia (Plurinational State of)", "United Republic of Tanzania", "Bulgaria", "Burundi", "Argentina", "Turkmenistan", "Bangladesh", "Tonga", "Trinidad and Tobago", "Bahrain", "Burkina Faso", "Armenia", "Cambodia", "Bahamas", "Bhutan", "Botswana", "Central African Republic", "Belize", "Azerbaijan", "Afghanistan", "United Arab Emirates", "Ukraine", "Zambia", "Thailand", "Belgium", "Canada", "United Kingdom of Great Britain and Northern Ireland", "Benin", "Tunisia", "Cameroon", "Timor-Leste", "Belarus", "Algeria", "Brunei Darussalam", "Albania", "Austria", "Bosnia and Herzegovina", "Turkey", "Yemen"], "locationmode": "country names", "locations": ["Zimbabwe", "Singapore", "Eritrea", "Montenegro", "Sierra Leone", "Eswatini", "Seychelles", "Ethiopia", "Fiji", "Serbia", "Finland", "Senegal", "France", "Gabon", "Equatorial Guinea", "Saudi Arabia", "Sao Tome and Principe", "Georgia", "Germany", "Samoa", "Ghana", "Saint Vincent and the Grenadines", "Greece", "Grenada", "Saint Lucia", "Guatemala", "Rwanda", "Guinea", "Guinea-Bissau", "Gambia", "Slovakia", "El Salvador", "Egypt", "Chile", "Syrian Arab Republic", "China", "Switzerland", "Colombia", "Comoros", "Sweden", "Congo", "Suriname", "Costa Rica", "C\u00f4te d\u2019Ivoire", "Sudan (until 2011)", "Croatia", "Sri Lanka", "Cuba", "Cyprus", "Sp ...
# <div>                            <div id="2ce0d7aa-15cf-4cf2-b08c-2fa7875286f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ce0d7aa-15cf-4cf2-b08c-2fa7875286f2")) {                    Plotly.newPlot(                        "2ce0d7aa-15cf-4cf2-b08c-2fa7875286f2",                        [{"hovertemplate": "Sex=Both sexes<br>Location=India<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2015, 2010, 2000], "xaxis": "x2", "y": [70.79, 69.31, 67.23, 62.11], "yaxis": "y2"}, {"hovertemplate": "Sex=Both sexes<br>Location=Rest of the World<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2000, 2010, 2015, 2019], "xaxis": "x", "y": [66.7745054945055, 70.01972527472529, 71.51236263736266, 72.55010989010992], "yaxis": "y"}, {"hovertemplate": "Sex=Male<br>Location=India<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Male", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Male", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2015, 2010, 2000], "xaxis": "x2", "y": [69.52, 68.11, 65.69, 61.34], "yaxis": "y2"}, {"hovertemplate": "Sex=Male<br>Location=Rest of the World<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Male", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Male", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2000, 2010, 2015, 2019], "xaxis": "x", "y": [64.31313186813189, 67.59016483516487, 69.07065934065929, 70.13796703296703], "yaxis": "y"}, {"hovertemplate": "Sex=Female<br>Location=India<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Female", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Female", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2015, 2010, 2000], "xaxis": "x2", "y": [72.17, 70.62, 68.94, 62.92], "yaxis": "y2"}, {"hovertemplate": "Sex=Female<br>Location=Rest of the World<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Female", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Female", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2000, 2010, 2015, 2019], "xaxis": "x", "y": [69.3252197802198, 72.51840659340658, 74.00851648351647, 75.0126923076923], "yaxis": "y"}],                        {"annotations": [{"font": {}, "showarrow": false, "text": "Location=Rest of the World", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.2425, "yanchor": "middle", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Location=India", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.7575000000000001, "yanchor": "middle", "yref": "paper"}], "legend": {"title": {"text": "Sex"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{ ...

# %% [markdown]
# ## **Healthy Life Expectancy (HALE) at Birth (years)**

# %%
df_world = df_HALElifeExpectancyAtBirth[df_HALElifeExpectancyAtBirth['Dim1'] == 'Both sexes'].sort_values(by=['Period']).reset_index()
df_india = df_HALElifeExpectancyAtBirth[df_HALElifeExpectancyAtBirth['Location'] == 'India'].reset_index(drop=True)
df_restworld = df_HALElifeExpectancyAtBirth[df_HALElifeExpectancyAtBirth['Location'] != 'India'].reset_index(drop=True)
df_restworld = df_restworld.groupby(['Period', 'Dim1'])['First Tooltip'].mean().reset_index()
df_restworld['Location'] = 'Rest of the World'
df_world_vs_india = df_india.append(df_restworld).reset_index(drop=True)

# %%
df_world.rename(columns={'First Tooltip': 'Healthy Life Expectancy'}, inplace=True)
plot_worldmap(df_world, 'Location', 'Period', 'Healthy Life Expectancy', 'Healthy Life Expectancy (HALE) at Birth (years)')
df_world_vs_india.rename(columns={'Dim1': 'Sex', 'First Tooltip': 'Life Expectancy'}, inplace=True)
plot_world_vs_india(df_world_vs_india, 'Period', 'Life Expectancy', 'Sex', 'Location', 'Healthy Life Expectancy (HALE) at Birth (years)')
# Out:
# <div>                            <div id="43343d7a-a8e4-4b4e-afc0-9787140f2b35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43343d7a-a8e4-4b4e-afc0-9787140f2b35")) {                    Plotly.newPlot(                        "43343d7a-a8e4-4b4e-afc0-9787140f2b35",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>Period=2000<br>Location=%{location}<br>Healthy Life Expectancy=%{z}<extra></extra>", "hovertext": ["Zimbabwe", "Singapore", "Eritrea", "Montenegro", "Sierra Leone", "Eswatini", "Seychelles", "Ethiopia", "Fiji", "Serbia", "Finland", "Senegal", "France", "Gabon", "Equatorial Guinea", "Saudi Arabia", "Sao Tome and Principe", "Georgia", "Germany", "Samoa", "Ghana", "Saint Vincent and the Grenadines", "Greece", "Grenada", "Saint Lucia", "Guatemala", "Rwanda", "Guinea", "Guinea-Bissau", "Gambia", "Slovakia", "El Salvador", "Egypt", "Chile", "Syrian Arab Republic", "China", "Switzerland", "Colombia", "Comoros", "Sweden", "Congo", "Suriname", "Costa Rica", "C\u00f4te d\u2019Ivoire", "Sudan (until 2011)", "Croatia", "Sri Lanka", "Cuba", "Cyprus", "Spain", "Czechia", "South Sudan", "Democratic People's Republic of Korea", "Democratic Republic of the Congo", "South Africa", "Denmark", "Somalia", "Djibouti", "Dominican Republic", "Solomon Islands", "Ecuador", "Slovenia", "Russian Federation", "Chad", "Guyana", "Haiti", "Lebanon", "Norway", "Lesotho", "Nigeria", "Liberia", "Libya", "Niger", "Lithuania", "Nicaragua", "Luxembourg", "Madagascar", "New Zealand", "Malawi", "Latvia", "Netherlands", "Maldives", "Nepal", "Mali", "Namibia", "Malta", "Mauritania", "Myanmar", "Mauritius", "Mozambique", "Mexico", "Micronesia (Federated States of)", "Morocco", "Mongolia", "Malaysia", "Oman", "Lao People's Democratic Republic", "Kyrgyzstan", "Honduras", "The former Yugoslav Republic of Macedonia", "Hungary", "Republic of Moldova", "Iceland", "India", "Republic of Korea", "Indonesia", "Qatar", "Iran (Islamic Republic of)", "Iraq", "Portugal", "Ireland", "Poland", "Israel", "Italy", "Philippines", "Jamaica", "Peru", "Japan", "Jordan", "Paraguay", "Kazakhstan", "Papua New Guinea", "Kenya", "Kiribati", "Panama", "Kuwait", "Pakistan", "Romania", "Tajikistan", "Estonia", "Brazil", "Vanuatu", "Uganda", "Angola", "Viet Nam", "Uzbekistan", "Barbados", "Togo", "United States of America", "Cabo Verde", "Australia", "Antigua and Barbuda", "Uruguay", "Venezuela (Bolivarian Republic of)", "Bolivia (Plurinational State of)", "United Republic of Tanzania", "Bulgaria", "Burundi", "Argentina", "Turkmenistan", "Bangladesh", "Tonga", "Trinidad and Tobago", "Bahrain", "Burkina Faso", "Armenia", "Cambodia", "Bahamas", "Bhutan", "Botswana", "Central African Republic", "Belize", "Azerbaijan", "Afghanistan", "United Arab Emirates", "Ukraine", "Zambia", "Thailand", "Belgium", "Canada", "United Kingdom of Great Britain and Northern Ireland", "Benin", "Tunisia", "Cameroon", "Timor-Leste", "Belarus", "Algeria", "Brunei Darussalam", "Albania", "Austria", "Bosnia and Herzegovina", "Turkey", "Yemen"], "locationmode": "country names", "locations": ["Zimbabwe", "Singapore", "Eritrea", "Montenegro", "Sierra Leone", "Eswatini", "Seychelles", "Ethiopia", "Fiji", "Serbia", "Finland", "Senegal", "France", "Gabon", "Equatorial Guinea", "Saudi Arabia", "Sao Tome and Principe", "Georgia", "Germany", "Samoa", "Ghana", "Saint Vincent and the Grenadines", "Greece", "Grenada", "Saint Lucia", "Guatemala", "Rwanda", "Guinea", "Guinea-Bissau", "Gambia", "Slovakia", "El Salvador", "Egypt", "Chile", "Syrian Arab Republic", "China", "Switzerland", "Colombia", "Comoros", "Sweden", "Congo", "Suriname", "Costa Rica", "C\u00f4te d\u2019Ivoire", "Sudan (until 2011)", "Croatia", "Sri Lanka", "Cuba", "Cypr ...
# <div>                            <div id="0cdf8d4b-e8a1-423c-a8e6-1b39ab21acbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cdf8d4b-e8a1-423c-a8e6-1b39ab21acbe")) {                    Plotly.newPlot(                        "0cdf8d4b-e8a1-423c-a8e6-1b39ab21acbe",                        [{"hovertemplate": "Sex=Both sexes<br>Location=India<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2015, 2010, 2000], "xaxis": "x2", "y": [60.33, 59.14, 57.32, 52.95], "yaxis": "y2"}, {"hovertemplate": "Sex=Both sexes<br>Location=Rest of the World<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2000, 2010, 2015, 2019], "xaxis": "x", "y": [58.50302197802196, 61.289505494505526, 62.51769230769234, 63.33137362637359], "yaxis": "y"}, {"hovertemplate": "Sex=Male<br>Location=India<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Male", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Male", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2015, 2010, 2000], "xaxis": "x2", "y": [60.28, 59.12, 57.03, 53.19], "yaxis": "y2"}, {"hovertemplate": "Sex=Male<br>Location=Rest of the World<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Male", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Male", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2000, 2010, 2015, 2019], "xaxis": "x", "y": [57.1306043956044, 59.99065934065937, 61.22445054945057, 62.08104395604395], "yaxis": "y"}, {"hovertemplate": "Sex=Female<br>Location=India<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Female", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Female", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2015, 2010, 2000], "xaxis": "x2", "y": [60.39, 59.16, 57.65, 52.68], "yaxis": "y2"}, {"hovertemplate": "Sex=Female<br>Location=Rest of the World<br>Period=%{x}<br>Life Expectancy=%{y}<extra></extra>", "legendgroup": "Female", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Female", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2000, 2010, 2015, 2019], "xaxis": "x", "y": [59.91653846153849, 62.6101098901099, 63.819999999999986, 64.58423076923079], "yaxis": "y"}],                        {"annotations": [{"font": {}, "showarrow": false, "text": "Location=Rest of the World", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.2425, "yanchor": "middle", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Location=India", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.7575000000000001, "yanchor": "middle", "yref": "paper"}], "legend": {"title": {"text": "Sex"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": ...

# %% [markdown]
# # **Maternal Mortality**

# %% [markdown]
# ## **Neonatal Mortality Rate (per 1000 live births)**

# %%
df_neonatalMortalityRate['First Tooltip'] = df_neonatalMortalityRate['First Tooltip'].str.split('[', expand=True)[0]
df_neonatalMortalityRate['First Tooltip'] = df_neonatalMortalityRate['First Tooltip'].astype('float')
df_world = df_neonatalMortalityRate[df_neonatalMortalityRate['Dim1'] == 'Both sexes'].sort_values(by=['Period']).reset_index()
df_india = df_neonatalMortalityRate[df_neonatalMortalityRate['Location'] == 'India'].reset_index(drop=True)
df_restworld = df_neonatalMortalityRate[df_neonatalMortalityRate['Location'] != 'India'].reset_index(drop=True)
df_restworld = df_restworld.groupby(['Period', 'Dim1'])['First Tooltip'].mean().reset_index()
df_restworld['Location'] = 'Rest of the World'
df_world_vs_india = df_india.append(df_restworld).reset_index(drop=True)

# %%
df_world.rename(columns={'First Tooltip': 'Neonatal Mortality Rate'}, inplace=True)
plot_worldmap(df_world, 'Location', 'Period', 'Neonatal Mortality Rate', 'Neonatal Mortality Rate (per 1000 live births)')
df_world_vs_india.rename(columns={'Dim1': 'Sex', 'First Tooltip': 'Neonatal Mortality Rate'}, inplace=True)
plot_world_vs_india(df_world_vs_india, 'Period', 'Neonatal Mortality Rate', 'Sex', 'Location', 'Neonatal Mortality Rate (per 1000 live births)')
# Out:
# <div>                            <div id="1dba682d-c30c-4a6d-93cf-1c0168400bd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dba682d-c30c-4a6d-93cf-1c0168400bd5")) {                    Plotly.newPlot(                        "1dba682d-c30c-4a6d-93cf-1c0168400bd5",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>Period=1951<br>Location=%{location}<br>Neonatal Mortality Rate=%{z}<extra></extra>", "hovertext": ["Republic of Korea", "Malaysia"], "locationmode": "country names", "locations": ["Republic of Korea", "Malaysia"], "name": "", "type": "choropleth", "z": [43.48, 29.64]}],                        {"coloraxis": {"colorbar": {"title": {"text": "Neonatal Mortality Rate"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "showcoastlines": false, "showframe": false}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Period="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1951"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1951", "method": "animate"}, {"args": [["1952"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1952", "method": "animate"}, {"args": [["1953"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1953", "method": "animate"}, {"args": [["1954"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1954", "method": "animate"}, {"args": [["1955"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1955", "method": "animate"}, {"args": [["1956"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1956", "method": "animate"}, {"args": [["1957"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1957", "method": "animate"}, {"args": [["1958"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1958", "method": "animate"}, {"args": [["1959"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1959", "method": "animate"}, {"args": [["1960"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1960", "method": "animate"}, {"args": [["1961"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1961", "method": "animate"}, {"args": [["1962"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1962", "method": "animate"}, {"args": [["1963"], {"frame": {"duration": 0, "redra ...
# <div>                            <div id="c006a91a-f94b-4ec0-9119-a85f83922019" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c006a91a-f94b-4ec0-9119-a85f83922019")) {                    Plotly.newPlot(                        "c006a91a-f94b-4ec0-9119-a85f83922019",                        [{"hovertemplate": "Sex=Both sexes<br>Location=India<br>Period=%{x}<br>Neonatal Mortality Rate=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975], "xaxis": "x2", "y": [21.66, 22.62, 23.65, 24.74, 25.87, 27.06, 28.26, 29.49, 30.73, 31.98, 33.21, 34.43, 35.65, 36.86, 38.12, 39.42, 40.78, 42.16, 43.58, 44.99, 46.38, 47.74, 49.04, 50.27, 51.47, 52.61, 53.78, 54.94, 56.13, 57.4, 58.75, 60.13, 61.55, 63.02, 64.49, 65.94, 67.39, 68.87, 70.4, 72.01, 73.65, 75.27, 76.93, 78.47, 79.89], "yaxis": "y2"}, {"hovertemplate": "Sex=Both sexes<br>Location=Rest of the World<br>Period=%{x}<br>Neonatal Mortality Rate=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [36.56, 62.4725, 60.174285714285716, 55.3965, 51.83111111111111, 51.23678571428571, 51.36266666666668, 51.202812500000014, 51.38575757575759, 42.04127659574468, 41.28000000000001, 41.57708333333333, 42.3943137254902, 42.79218181818183, 42.589838709677416, 42.47793650793652, 42.11323076923077, 39.06613333333334, 38.89955555555556, 37.607978723404244, 37.100918367346935, 36.2378431372549, 36.163238095238114, 35.454629629629636, 33.735405405405395, 33.29053571428572, 33.020932203389826, 32.11949579831933, 31.47680327868853, 30.766451612903232, 29.795999999999996, 28.623731343283577, 28.076666666666682, 27.43800000000001, 26.615902777777777, 26.169727891156462, 26.18342281879195, 25.502119205298033, 24.645260416666662, 24.156406249999986, 23.72078125, 23.317291666666677, 22.9175, 22.510156250000005, 22.076302083333342, 21.62307291666667, 21.1571875, 20.67020833333333, 20.158437499999994, 19.638177083333332, 19.116041666666664, 18.606406250000003, 18.121145833333333, 17.659114583333338, 17.21416666666666, 16.784895833333348, 16.374895833333326, 15.982864583333333, 15.597291666666672, 15.246458333333337, 14.892552083333335, 14.56911458333334, 14.256458333333335, 13.95119791666667, 13.666666666666663, 13.375156249999991, 13.084427083333338, 12.798541666666672, 12.514791666666667], "yaxis": "y"}],                        {"annotations": [{"font": {}, "showarrow": false, "text": "Location=Rest of the World", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.2425, "yanchor": "middle", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Location=India", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.7575000000000001, "yanchor": "middle", "yref": "paper"}], "legend": {"title": {"text": "Sex"}, "tracegroupgap": 0}, "margin": {"t": 60}, "te ...

# %% [markdown]
# ## **Under-Five Mortality Rate (probability of dying by age 5 per 1000 live births)**

# %%
df_under5MortalityRate['First Tooltip'] = df_under5MortalityRate['First Tooltip'].str.split('[', expand=True)[0]
df_under5MortalityRate['First Tooltip'] = df_under5MortalityRate['First Tooltip'].astype('float')
df_world = df_under5MortalityRate[df_under5MortalityRate['Dim1'] == 'Both sexes'].sort_values(by=['Period']).reset_index()
df_india = df_under5MortalityRate[df_under5MortalityRate['Location'] == 'India'].reset_index(drop=True)
df_restworld = df_under5MortalityRate[df_under5MortalityRate['Location'] != 'India'].reset_index(drop=True)
df_restworld = df_restworld.groupby(['Period', 'Dim1'])['First Tooltip'].mean().reset_index()
df_restworld['Location'] = 'Rest of the World'
df_world_vs_india = df_india.append(df_restworld).reset_index(drop=True)

# %%
df_world.rename(columns={'First Tooltip': 'Under-Five Mortality Rate'}, inplace=True)
plot_worldmap(df_world, 'Location', 'Period', 'Under-Five Mortality Rate', 'Under-Five Mortality Rate (probability of dying by age 5 per 1000 live births)')
df_world_vs_india.rename(columns={'Dim1': 'Sex', 'First Tooltip': 'Under-Five Mortality Rate'}, inplace=True)
plot_world_vs_india(df_world_vs_india, 'Period', 'Under-Five Mortality Rate', 'Sex', 'Location', 'Under-Five Mortality Rate (probability of dying by age 5 per 1000 live births)')
# Out:
# <div>                            <div id="3d486b0f-95f9-41be-aa7c-ca51a33d1af3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d486b0f-95f9-41be-aa7c-ca51a33d1af3")) {                    Plotly.newPlot(                        "3d486b0f-95f9-41be-aa7c-ca51a33d1af3",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>Period=1950<br>Location=%{location}<br>Under-Five Mortality Rate=%{z}<extra></extra>", "hovertext": ["Senegal", "Poland", "Guinea", "Austria", "Singapore", "New Zealand", "Sweden", "Saint Lucia", "Australia", "Cabo Verde", "Guyana", "Denmark", "Switzerland", "Antigua and Barbuda", "Samoa", "Hungary", "Canada", "Ireland", "Luxembourg", "Seychelles", "Italy", "Mauritius", "Dominican Republic", "Burkina Faso", "Malta", "Benin", "France", "Finland", "Japan", "Fiji", "Belgium", "Eswatini", "Ghana", "Iceland", "Barbados", "Mauritania", "Brunei Darussalam", "Bangladesh", "Greece", "Portugal", "Bulgaria", "Grenada", "Malaysia", "Norway", "Netherlands", "Costa Rica", "Jordan", "Iraq", "Thailand"], "locationmode": "country names", "locations": ["Senegal", "Poland", "Guinea", "Austria", "Singapore", "New Zealand", "Sweden", "Saint Lucia", "Australia", "Cabo Verde", "Guyana", "Denmark", "Switzerland", "Antigua and Barbuda", "Samoa", "Hungary", "Canada", "Ireland", "Luxembourg", "Seychelles", "Italy", "Mauritius", "Dominican Republic", "Burkina Faso", "Malta", "Benin", "France", "Finland", "Japan", "Fiji", "Belgium", "Eswatini", "Ghana", "Iceland", "Barbados", "Mauritania", "Brunei Darussalam", "Bangladesh", "Greece", "Portugal", "Bulgaria", "Grenada", "Malaysia", "Norway", "Netherlands", "Costa Rica", "Jordan", "Iraq", "Thailand"], "name": "", "type": "choropleth", "z": [337.8, 119.2, 356.4, 83.48, 142.5, 35.52, 27.21, 202.3, 31.58, 209.8, 153.5, 33.97, 38.54, 119.1, 155.6, 104.0, 48.57, 54.23, 62.38, 116.8, 88.52, 114.6, 147.2, 381.0, 101.1, 349.1, 57.11, 43.26, 91.32, 142.9, 54.64, 239.5, 254.0, 29.62, 171.2, 307.8, 211.5, 345.2, 57.63, 139.4, 129.1, 150.0, 166.3, 32.87, 31.89, 127.2, 275.7, 357.4, 207.8]}],                        {"coloraxis": {"colorbar": {"title": {"text": "Under-Five Mortality Rate"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "showcoastlines": false, "showframe": false}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Period="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1950"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1950", "method": "animate"}, {"args": [["1951"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1951", "method": "animate"}, {"args": [["1952"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1952", "method": "animate"}, {"args": [["1953"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1953", "method": "animate"}, {"args": [["1954"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1 ...
# <div>                            <div id="f039a2c4-b755-4030-bb04-7797a174490b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f039a2c4-b755-4030-bb04-7797a174490b")) {                    Plotly.newPlot(                        "f039a2c4-b755-4030-bb04-7797a174490b",                        [{"hovertemplate": "Sex=Both sexes<br>Location=India<br>Period=%{x}<br>Under-Five Mortality Rate=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975], "xaxis": "x2", "y": [34.27, 36.29, 38.52, 40.95, 43.52, 46.22, 49.07, 52.02, 55.09, 58.23, 61.45, 64.69, 67.95, 71.2, 74.47, 77.77, 81.15, 84.61, 88.16, 91.78, 95.41, 99.01, 102.6, 106.1, 109.5, 112.8, 116.1, 119.4, 122.7, 126.2, 130.0, 133.8, 137.8, 141.7, 145.6, 149.5, 153.6, 158.0, 162.8, 167.9, 173.3, 178.9, 184.4, 189.6, 194.5], "yaxis": "y2"}, {"hovertemplate": "Sex=Both sexes<br>Location=Rest of the World<br>Period=%{x}<br>Under-Five Mortality Rate=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [147.70081632653066, 155.5375438596491, 157.81109375000003, 156.14720588235286, 154.53985714285713, 155.79717948717953, 159.2411627906977, 156.17011363636365, 150.81322222222224, 150.57399999999998, 149.06404040404036, 144.389393939394, 143.94623762376239, 142.7059223300971, 141.93728971962622, 141.1771818181818, 138.57180180180185, 135.23991304347825, 130.79563025210084, 128.84637096774196, 125.75547619047614, 121.77230769230772, 119.9568656716418, 116.85977611940301, 113.84401459854016, 111.06784172661877, 107.89425531914891, 104.64307142857143, 102.63020833333331, 98.65062068965516, 96.63476510067113, 91.12896774193548, 89.77430379746833, 86.89484276729551, 83.40858024691352, 79.8384705882353, 77.63611764705882, 75.57499999999993, 73.80452941176472, 71.82617647058825, 70.17376470588233, 68.71052941176472, 67.35276470588232, 66.08311764705881, 65.24094117647064, 63.62929411764708, 61.750705882352904, 60.275823529411774, 58.81023529411763, 56.667529411764704, 54.67258823529412, 52.94923976608188, 50.901637426900585, 48.92081871345031, 47.15169590643272, 45.16736842105265, 43.371812865497084, 41.6480701754386, 40.13040935672514, 38.42052631578948, 37.5985380116959, 35.4595321637427, 34.187309941520475, 33.005964912280696, 31.97046783625732, 30.938947368421054, 29.89204678362574, 28.97497076023393, 28.03584795321637, 27.150350877192967], "yaxis": "y"}, {"hovertemplate": "Sex=Male<br>Location=India<br>Period=%{x}<br>Under-Five Mortality Rate=%{y}<extra></extra>", "legendgroup": "Male", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Male", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, ...

# %% [markdown]
# # **Communicable Diseases**

# %% [markdown]
# ## **New HIV Infections (per 1000 uninfected population)**

# %%
df_newHivInfections = df_newHivInfections[df_newHivInfections['First Tooltip']!='No data'].reset_index(drop=True)
df_newHivInfections['First Tooltip'] = df_newHivInfections['First Tooltip'].str.replace('<', '').str.split('[', expand=True)[0]
df_newHivInfections['First Tooltip'] = df_newHivInfections['First Tooltip'].astype('float')
df_world = df_newHivInfections[df_newHivInfections['Dim1'] == 'Both sexes'].sort_values(by=['Period']).reset_index()
df_india = df_newHivInfections[df_newHivInfections['Location'] == 'India'].reset_index(drop=True)
df_restworld = df_newHivInfections[df_newHivInfections['Location'] != 'India'].reset_index(drop=True)
df_restworld = df_restworld.groupby(['Period', 'Dim1'])['First Tooltip'].mean().reset_index()
df_restworld['Location'] = 'Rest of the World'
df_world_vs_india = df_india.append(df_restworld).reset_index(drop=True)

# %%
df_world.rename(columns={'First Tooltip': 'New HIV Infections'}, inplace=True)
plot_worldmap(df_world, 'Location', 'Period', 'New HIV Infections', 'New HIV Infections (per 1000 uninfected population)')
df_world_vs_india.rename(columns={'Dim1': 'Sex', 'First Tooltip': 'New HIV Infections'}, inplace=True)
plot_world_vs_india(df_world_vs_india, 'Period', 'New HIV Infections', 'Sex', 'Location', 'New HIV Infections (per 1000 uninfected population)')
# Out:
# <div>                            <div id="47e6dfea-c311-42f5-a37f-923590a0a748" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47e6dfea-c311-42f5-a37f-923590a0a748")) {                    Plotly.newPlot(                        "47e6dfea-c311-42f5-a37f-923590a0a748",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>Period=2000<br>Location=%{location}<br>New HIV Infections=%{z}<extra></extra>", "hovertext": ["Latvia", "Guinea", "Guinea-Bissau", "Guyana", "Haiti", "Honduras", "Iran (Islamic Republic of)", "Italy", "Jamaica", "Kazakhstan", "Guatemala", "Kenya", "Lao People's Democratic Republic", "Lebanon", "Lesotho", "Liberia", "Libya", "Lithuania", "Madagascar", "Malawi", "Malaysia", "Kyrgyzstan", "Ghana", "Gambia", "Gabon", "Chad", "Chile", "Colombia", "Comoros", "Congo", "Costa Rica", "C\u00f4te d\u2019Ivoire", "Croatia", "Cuba", "Democratic Republic of the Congo", "Djibouti", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "Equatorial Guinea", "Eritrea", "Eswatini", "Ethiopia", "Fiji", "France", "Mauritius", "Mongolia", "Montenegro", "Morocco", "Spain", "Sri Lanka", "Sudan (until 2011)", "Suriname", "Switzerland", "Syrian Arab Republic", "Tajikistan", "Thailand", "Timor-Leste", "Togo", "Trinidad and Tobago", "Tunisia", "Uganda", "Ukraine", "United Republic of Tanzania", "United States of America", "Uzbekistan", "Venezuela (Bolivarian Republic of)", "Viet Nam", "Yemen", "Zambia", "South Sudan", "Central African Republic", "South Africa", "Singapore", "Mozambique", "Myanmar", "Namibia", "Nepal", "Netherlands", "New Zealand", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Papua New Guinea", "Paraguay", "Peru", "Philippines", "Republic of Moldova", "Romania", "Rwanda", "Senegal", "Serbia", "Sierra Leone", "Somalia", "Cameroon", "Zimbabwe", "Belarus", "Argentina", "Angola", "Burundi", "Burkina Faso", "Algeria", "Armenia", "Cabo Verde", "Bolivia (Plurinational State of)", "Botswana", "Albania", "Australia", "Benin", "Cambodia", "Bulgaria", "Barbados", "Afghanistan", "Azerbaijan", "Brazil"], "locationmode": "country names", "locations": ["Latvia", "Guinea", "Guinea-Bissau", "Guyana", "Haiti", "Honduras", "Iran (Islamic Republic of)", "Italy", "Jamaica", "Kazakhstan", "Guatemala", "Kenya", "Lao People's Democratic Republic", "Lebanon", "Lesotho", "Liberia", "Libya", "Lithuania", "Madagascar", "Malawi", "Malaysia", "Kyrgyzstan", "Ghana", "Gambia", "Gabon", "Chad", "Chile", "Colombia", "Comoros", "Congo", "Costa Rica", "C\u00f4te d\u2019Ivoire", "Croatia", "Cuba", "Democratic Republic of the Congo", "Djibouti", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "Equatorial Guinea", "Eritrea", "Eswatini", "Ethiopia", "Fiji", "France", "Mauritius", "Mongolia", "Montenegro", "Morocco", "Spain", "Sri Lanka", "Sudan (until 2011)", "Suriname", "Switzerland", "Syrian Arab Republic", "Tajikistan", "Thailand", "Timor-Leste", "Togo", "Trinidad and Tobago", "Tunisia", "Uganda", "Ukraine", "United Republic of Tanzania", "United States of America", "Uzbekistan", "Venezuela (Bolivarian Republic of)", "Viet Nam", "Yemen", "Zambia", "South Sudan", "Central African Republic", "South Africa", "Singapore", "Mozambique", "Myanmar", "Namibia", "Nepal", "Netherlands", "New Zealand", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Papua New Guinea", "Paraguay", "Peru", "Philippines", "Republic of Moldova", "Romania", "Rwanda", "Senegal", "Serbia", "Sierra Leone", "Somalia", "Cameroon", "Zimbabwe", "Belarus", "Argentina", "Angola", "Burundi", "Burkina Faso", "Algeria", "Armenia", "Cabo Verde", "Bolivia (Plurinational State of)", "Botswana", "Albania", "Australia", "Benin", "Cambodia", "Bulgaria", "Barbados", "Afghanistan", "Azerbaijan", ...
# <div>                            <div id="09c1cf59-710c-4699-8589-ea0d5d9ac501" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09c1cf59-710c-4699-8589-ea0d5d9ac501")) {                    Plotly.newPlot(                        "09c1cf59-710c-4699-8589-ea0d5d9ac501",                        [{"hovertemplate": "Sex=Both sexes<br>Location=Rest of the World<br>Period=%{x}<br>New HIV Infections=%{y}<extra></extra>", "legendgroup": "Both sexes", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Both sexes", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2000, 2005, 2010, 2015, 2019], "xaxis": "x", "y": [1.7110169491525422, 1.3096610169491523, 1.0505932203389827, 0.7740677966101698, 0.5895689655172415], "yaxis": "y"}, {"hovertemplate": "Sex=Female<br>Location=Rest of the World<br>Period=%{x}<br>New HIV Infections=%{y}<extra></extra>", "legendgroup": "Female", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Female", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2000, 2005, 2010, 2015, 2019], "xaxis": "x", "y": [1.9381739130434779, 1.4780869565217394, 1.1942608695652177, 0.8830434782608699, 0.6574561403508773], "yaxis": "y"}, {"hovertemplate": "Sex=Male<br>Location=Rest of the World<br>Period=%{x}<br>New HIV Infections=%{y}<extra></extra>", "legendgroup": "Male", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Male", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2000, 2005, 2010, 2015, 2019], "xaxis": "x", "y": [1.569478260869565, 1.205217391304348, 0.9595652173913045, 0.7072173913043481, 0.5455263157894739], "yaxis": "y"}],                        {"annotations": [{"font": {}, "showarrow": false, "text": "Location=Rest of the World", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.5, "yanchor": "middle", "yref": "paper"}], "legend": {"title": {"text": "Sex"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, ...

# %% [markdown]
# # **This work is in progress. Feel free to <span style="color:red"> Upvote </span> and give <span style="color:blue"> Feedback </span>.**
