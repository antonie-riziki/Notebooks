# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

sb.set()

# %%
df = pd.read_csv(r"D:\Open Classroom\Data Files\week2\week2\richmond_collisions.csv")
pd.set_option("display.max_rows", 50)
pd.set_option("display.max_columns", 100)
df.head()
# Out:
#     CASEID     POINT_X    POINT_Y  YEAR_  LOCATION CHPTYPE  DAYWEEK  CRASHSEV  \
# 0  1785833 -122.337733  37.976154   2005       710       0        6         3
# 1  1785837 -122.344543  37.939667   2005       710       0        7         4
# 2  1785883 -122.347521  37.941422   2005       710       0        6         4
# 3  1785899 -122.323523  37.914116   2005       710       0        7         4
# 4  1830750 -122.324561  37.940150   2005       710       1        7         4
#
#   VIOLCAT  KILLED  INJURED WEATHER1 PEDCOL BICCOL MCCOL TRUCKCOL ETOH  \
# 0      09       0        1        B    NaN    NaN   NaN      NaN  NaN
# 1      09       0        2        B    NaN    NaN   NaN      NaN  NaN
# 2      09       0        1        C    NaN    NaN   NaN      NaN  NaN
# 3      12       0        2        B    NaN    NaN   NaN      NaN  NaN
# 4      18       0        1        B    NaN    NaN   NaN      NaN  NaN
#
#    TIMECAT  MONTH_ CRASHTYP INVOLVE PED         PRIMARYRD       SECONDRD  \
# 0     2400       1        D       C   A  ROBERT H  MILLER  BIRMINGHAM AV
# 1     1200       1        D       C   A      ROOSEVELT AV        25TH ST
# 2     1500       1        D       C   A           23RD ST       GRANT AV
# 3     1500       1        D       C   A        CARLSON BL     BAYVIEW AV
# 4     1500       1        E       J   A             RT 80   SAN PABLO AV
#
#    DISTANCE DIRECT INTERSECT_    PROCDATE  JURIS       DATE_  TIME_  BADGE  \
# 0         0    NaN          Y  2005-06-03    710  2005-01-01   2100   1220
# 1         0    NaN          Y  2005-05-26    710  2005-01-02   1135   1242
# 2         6      N          N  2005-06-03    710  2005-01-01   1300   1401
# 3         0    NaN          Y  2005-06-15    710  2005-01-02   1435   1220
# 4      1056      E          N  2005-08-04   9370  2005-01-02   1438  01721
#
#   JURIDIST  SHIFT  POP  SPECIAL  BEATTYPE  LAPDDIV  BEATCLAS BEATNUMB  \
# 0      NaN      5    5        0         0      NaN         0      NaN
# 1      NaN      5    5        0         0      NaN         0      NaN
# 2       NE      5    5        0         0      NaN         0      010
# 3      NaN      5    5        0         0      NaN         0      NaN
# 4      NaN      2    5        0         1      NaN         2      082
#
#   WEATHER2 STATEHW CALTRANC  CALTRAND  STROUTE ROUTESUF POSTPRE  POSTMILE  \
# 0        C       N      NaN         0        0      NaN     NaN      0.00
# 1        C       N      NaN         0        0      NaN     NaN      0.00
# 2        -       N      NaN         0        0      NaN     NaN      0.00
# 3        C       N      NaN         0        0      NaN     NaN      0.00
# 4        C       Y       CC         4       80        -       -      3.19
#
#   LOCATYPE RAMP SIDEHW TOWAWAY  PARTIES PCF VIOLCODE   VIOL VIOLSUB HITRUN  \
# 0      NaN  NaN    NaN       Y        2   A        -  21802       A      M
# 1      NaN  NaN    NaN       Y        2   A        -  21800       A      N
# 2      NaN  NaN    NaN       N        2   A        -  21802       A      N
# 3      NaN  NaN    NaN       Y        4   A        -  21453       A      N
# 4        H    -      E       N        1   C        -      0     NaN      N
#
#   ROADSURF RDCOND1 RDCOND2 LIGHTING RIGHTWAY  CHPRDTYP NOTPRIV STFAULT  \
# 0        B       H       -        C        A         0       Y       -
# 1        B       H       -        A        A         0       Y       A
# 2        B       H       -        A        A         0       Y       A
# 3        B       H       -        A        A         0       Y       -
# 4        B       H       -        A        D         6       Y       -
#
#   CHPFAULT  SEVINJ  OTHERINJ  COP  PEDKILL  PEDINJ  BICKILL  BICINJ  MCKILL  \
# 0        -       0         1    0        0       0        0       0       0
# 1      NaN       0         0    2        0       0        0       0       0
# 2      NaN       0         0    1        0       0        0       0       0
# 3        -       0         0    2        0       0        0       0       0
# 4        -       0         0    1        0       0        0       0       0
#
#    MCINJURE RAMP1 RAMP2      CITY        COUNTY STATE  X_CHP  Y_CHP
# 0         0     -     -  RICHMOND  CONTRA COSTA    CA    0.0    0.0
# 1         0     -     -  RICHMOND  CONTRA COSTA    CA    0.0    0.0
# 2         0     -     -  RICHMOND  CONTRA COSTA    CA    0.0    0.0
# 3         0     -     -  RICHMOND  CONTRA COSTA    CA    0.0    0.0
# 4         0     -     -  RICHMOND  CONTRA COSTA    CA    0.0    0.0

# %%
df["DATE_"] = pd.to_datetime(df["DATE_"])
df.loc[0, "DATE_"]
# Out:
# Timestamp('2005-01-01 00:00:00')

# %%
df = df.set_index(df["DATE_"])

# %%
injuredMonthly = df["KILLED"].resample("y").sum().plot()
