# %% [markdown]
# # MOVIE DATASET RATINGS

# %% [markdown]
# #### Import Relevant Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import missingno as msno
import autoreload
import csv
import os
import sys

sb.set()
sb.set_style('darkgrid')

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 1000)

# %matplotlib inline

# %% [markdown]
# #### Load Dataset

# %%
df = pd.read_csv("D:\Open Classroom\Datasets\Movie Dataset Rating 1\Movie-Dataset-Latest.csv")
df.head()
# Out:
#    Unnamed: 0      id                        title release_date  \
# 0           0   19404  Dilwale Dulhania Le Jayenge   1995-10-20
# 1           1     278     The Shawshank Redemption   1994-09-23
# 2           2     238                The Godfather   1972-03-14
# 3           3  724089    Gabriel's Inferno Part II   2020-07-31
# 4           4     424             Schindler's List   1993-11-30
#
#                                             overview  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      25.884
# 1  Framed in the 1940s for the double murder of h...      60.110
# 2  Spanning the years 1945 to 1955, a chronicle o...      62.784
# 3  Professor Gabriel Emerson finally learns the t...      28.316
# 4  The true story of how businessman Oskar Schind...      38.661
#
#    vote_average  vote_count  video
# 0           8.7        3304  False
# 1           8.7       20369  False
# 2           8.7       15219  False
# 3           8.6        1360  False
# 4           8.6       12158  False

# %% [markdown]
# #### Statistical Information

# %%
df.shape
# Out:
# (9463, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9463 entries, 0 to 9462
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9463 non-null   int64
#  1   id            9463 non-null   int64
#  2   title         9463 non-null   object
#  3   release_date  9463 non-null   object
#  4   overview      9449 non-null   object
#  5   popularity    9463 non-null   float64
#  6   vote_average  9463 non-null   float64
#  7   vote_count    9463 non-null   int64
#  8   video         9463 non-null   bool
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 600.8+ KB

# %%
df.describe().round()
# Out:
#        Unnamed: 0        id  popularity  vote_average  vote_count
# count      9463.0    9463.0      9463.0        9463.0      9463.0
# mean       4731.0  149335.0        36.0           7.0      1515.0
# std        2732.0  197421.0       233.0           1.0      2555.0
# min           0.0       5.0         1.0           2.0       200.0
# 25%        2366.0    9951.0         9.0           6.0       316.0
# 50%        4731.0   25846.0        13.0           7.0       584.0
# 75%        7096.0  290548.0        24.0           7.0      1434.0
# max        9462.0  876716.0     14137.0           9.0     30535.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# title            0
# release_date     0
# overview        14
# popularity       0
# vote_average     0
# vote_count       0
# video            0
# dtype: int64

# %%
msno.bar(df)

# %%
sb.pairplot(df)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)
df.head(2)
# Out:
#       id                        title release_date  \
# 0  19404  Dilwale Dulhania Le Jayenge   1995-10-20
# 1    278     The Shawshank Redemption   1994-09-23
#
#                                             overview  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      25.884
# 1  Framed in the 1940s for the double murder of h...      60.110
#
#    vote_average  vote_count  video
# 0           8.7        3304  False
# 1           8.7       20369  False

# %%
cols = [i for i in df.columns if df[i].isnull().sum()>0]
cols
# Out:
# ['overview']

# %%
for i in cols:
    df[i] = df[i].fillna('Nill')

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# release_date    0
# overview        0
# popularity      0
# vote_average    0
# vote_count      0
# video           0
# dtype: int64

# %%
[i for i in df.columns]
# Out:
# ['id',
#  'title',
#  'release_date',
#  'overview',
#  'popularity',
#  'vote_average',
#  'vote_count',
#  'video']

# %%
df['popularity'].mean()
# Out:
# 35.67818102081792

# %%
df['vote_average'].mean()
# Out:
# 6.596829758004861

# %%
df['vote_count'].mean()
# Out:
# 1515.0207122477016
