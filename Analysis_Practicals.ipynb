# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as plo
from plotly.offline import iplot
import seaborn as sb
from math import ceil, floor
sb.set()

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\Births.csv")
pd.set_option("display.max_rows", 300)
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
df["day"] = df["day"].replace(99, "NaN")
df["day"] = df["day"].dropna()#.astype(int)
nanas = (df["day"] == "NaN")
df = df.drop(index = df[nanas].index)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsUpdate1.csv")

# %%
#df["date"] = df["year"].astype(str) + "-" + df["month"].astype(str) #+ "-" + df["day"].astype(float).astype(str)
#df = df.drop(index = df["day"].index)
#df.tail(79)

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsUpdate1.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
df = df.dropna(axis = "index", how = "any")

# %%
df.tail(10)
# Out:
#        year  month   day gender  births
# 14707  1988     12  27.0      F    5633
# 14708  1988     12  27.0      M    5895
# 14709  1988     12  28.0      F    5858
# 14710  1988     12  28.0      M    5989
# 14711  1988     12  29.0      F    5760
# 14712  1988     12  29.0      M    5944
# 14713  1988     12  30.0      F    5742
# 14714  1988     12  30.0      M    6095
# 14715  1988     12  31.0      F    4435
# 14716  1988     12  31.0      M    4698

# %%
df["day"] = df["day"].astype(int)

# %%
df.head()
# Out:
#    year  month  day gender  births
# 0  1969      1    1      F    4046
# 1  1969      1    1      M    4440
# 2  1969      1    2      F    4454
# 3  1969      1    2      M    4548
# 4  1969      1    3      F    4548

# %%
df["date"] = df["year"].astype(str) + "-" + df["month"].astype(str) + "-" + df["day"].astype(str)

# %%
df.head()
# Out:
#    year  month  day gender  births      date
# 0  1969      1    1      F    4046  1969-1-1
# 1  1969      1    1      M    4440  1969-1-1
# 2  1969      1    2      F    4454  1969-1-2
# 3  1969      1    2      M    4548  1969-1-2
# 4  1969      1    3      F    4548  1969-1-3

# %%
df = df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDate.csv")
#df["date"] = pd.to_datetime(df["date"], format = "%Y-%m-%d")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDate.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
# Out:
#    year  month  day gender  births      date
# 0  1969      1    1      F    4046  1969-1-1
# 1  1969      1    1      M    4440  1969-1-1
# 2  1969      1    2      F    4454  1969-1-2
# 3  1969      1    2      M    4548  1969-1-2
# 4  1969      1    3      F    4548  1969-1-3

# %%
feb = df["date"] == "1969-2-29"
df[feb]
df.drop(index = df[feb].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDateFeb.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDateFeb.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
#df["date"] = pd.to_datetime(df["date"], format = "%Y-%m-%d")
# Out:
#    year  month  day gender  births      date
# 0  1969      1    1      F    4046  1969-1-1
# 1  1969      1    1      M    4440  1969-1-1
# 2  1969      1    2      F    4454  1969-1-2
# 3  1969      1    2      M    4548  1969-1-2
# 4  1969      1    3      F    4548  1969-1-3

# %%
dropThirty = df["date"] == "1969-2-30"
df[dropThirty]
df.drop(index = df[dropThirty].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsThirty.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsThirty.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
# Out:
#    year  month  day gender  births      date
# 0  1969      1    1      F    4046  1969-1-1
# 1  1969      1    1      M    4440  1969-1-1
# 2  1969      1    2      F    4454  1969-1-2
# 3  1969      1    2      M    4548  1969-1-2
# 4  1969      1    3      F    4548  1969-1-3

# %%
thirtyOne = df["date"] == "1969-2-31"
df.head()
df[thirtyOne]
df.drop(index = df[thirtyOne].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\Births_31.csv")
#nov = df["date"] == "1969-11-31"
#df.head()
#df.drop(index = df[nov].index, inplace = True)
#df.to_csv("D:\Open Classroom\Data Files\CDC Births\Cleaned_Births_Data.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\Births_31.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
aprlThirtyOne = df["date"] == "1969-4-31"
df[aprlThirtyOne]
df.drop(index = df[aprlThirtyOne].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsJune.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsJune.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
juneThirtyOne = df["date"] == "1969-6-31"
df[juneThirtyOne]
df.drop(index = df[juneThirtyOne].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsSep.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsSep.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
sept = df["date"] == "1969-9-31"
df[sept]
df.drop(index = df[sept].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsNov.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsNov.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
nov = df["date"] == "1969-11-31"
df.head()
df.drop(index = df[nov].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDec.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDec.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
feb = df["date"] == "1970-2-29"
df.drop(index = df[feb].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDec.csv")
#df = pd.to_datetime(df["date"], format = "%Y-%m-%d")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsDec.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
febThirty = df["date"] == "1970-2-30"
df.drop(index = df[febThirty].index, inplace = True)
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsFeb2.csv")
#df = pd.to_datetime(df["date"], format = "%Y-%m-%d")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsFeb2.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
febThirtyOne = df["date"] == "1970-2-31"
df.drop(index = df[febThirtyOne].index, inplace = True)
#df = pd.to_datetime(df["date"], format = "%Y-%m-%d")
df.to_csv("D:\Open Classroom\Data Files\CDC Births\BirthsFeb3.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\BirthsFeb3.csv")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
apr = df["date"] = 
df = pd.to_datetime(df["date"], format = "%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python38\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-6895fdec23bb> in <module>
#       2 df.drop(columns = ["Unnamed: 0"], inplace = True)
#       3 df.head()
# ----> 4 df = pd.to_datetime(df["date"], format = "%Y-%m-%d")
# ...

# %%
#df = pd.to_datetime(df["date"])

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\CDC Births\Cleaned_Births_Data.csv")
df.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, year, month, day, gender, births, date]
# Index: []

# %%
#df["date"] = pd.to_datetime(df["date"], format = "%Y-%m-%d")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\Kenya Data\9998bc53-b6c2-4e8f-b448-c2f38b66c3fa_Data.csv")
#for i in df.columns():
#    df.drop(index = df.columns().index, how = "any")
df.dropna(axis = "index", how = "any", inplace = True)
df.head()
# Out:
#   Country Name Country Code                                    Series Name  \
# 0        Kenya          KEN     GNI per capita, Atlas method (current US$)
# 1        Kenya          KEN             GDP per capita (constant 2010 US$)
# 2        Kenya          KEN             GNI per capita (constant 2010 US$)
# 3        Kenya          KEN  GNI per capita, PPP (current international $)
# 4        Kenya          KEN                              GDP (current LCU)
#
#          Series Code     1960 [YR1960]     1961 [YR1961]     1962 [YR1962]  \
# 0     NY.GNP.PCAP.CD                ..                ..               100
# 1     NY.GDP.PCAP.KD  537.461013064514  480.433254225248  509.491109762245
# 2     NY.GNP.PCAP.KD                ..                ..                ..
# 3  NY.GNP.PCAP.PP.CD                ..                ..                ..
# 4     NY.GDP.MKTP.CN        5651898400        5663998500        6200798200
#
#       1963 [YR1963]     1964 [YR1964]     1965 [YR1965]  ...  \
# ...

# %%
df = pd.melt(df, id_vars = ["Country Name", "Country Code", "Series Name", "Series Code"],
            var_name = "Year",
            value_name = "GDP (%)").dropna(axis = "index", how = "any")
df.head()
# Out:
#   Country Name Country Code                                    Series Name  \
# 0        Kenya          KEN     GNI per capita, Atlas method (current US$)
# 1        Kenya          KEN             GDP per capita (constant 2010 US$)
# 2        Kenya          KEN             GNI per capita (constant 2010 US$)
# 3        Kenya          KEN  GNI per capita, PPP (current international $)
# 4        Kenya          KEN                              GDP (current LCU)
#
#          Series Code           Year           GDP (%)
# 0     NY.GNP.PCAP.CD  1960 [YR1960]                ..
# 1     NY.GDP.PCAP.KD  1960 [YR1960]  537.461013064514
# 2     NY.GNP.PCAP.KD  1960 [YR1960]                ..
# 3  NY.GNP.PCAP.PP.CD  1960 [YR1960]                ..
# 4     NY.GDP.MKTP.CN  1960 [YR1960]        5651898400

# %%
df.loc[0, "Year"][0:4]
# Out:
# '1960'

# %%
df[["Year", "Trash"]] = df["Year"].str.split("[", expand = True)
df["Year"] = df["Year"].astype(int)
df.head()
# Out:
#   Country Name Country Code                                    Series Name  \
# 0        Kenya          KEN     GNI per capita, Atlas method (current US$)
# 1        Kenya          KEN             GDP per capita (constant 2010 US$)
# 2        Kenya          KEN             GNI per capita (constant 2010 US$)
# 3        Kenya          KEN  GNI per capita, PPP (current international $)
# 4        Kenya          KEN                              GDP (current LCU)
#
#          Series Code  Year           GDP (%)    Trash
# 0     NY.GNP.PCAP.CD  1960                ..  YR1960]
# 1     NY.GDP.PCAP.KD  1960  537.461013064514  YR1960]
# 2     NY.GNP.PCAP.KD  1960                ..  YR1960]
# 3  NY.GNP.PCAP.PP.CD  1960                ..  YR1960]
# 4     NY.GDP.MKTP.CN  1960        5651898400  YR1960]

# %%
df.drop(columns = ["Trash", "Country Name", "Country Code"], inplace = True)
df.head()
# Out:
#                                      Series Name        Series Code  Year  \
# 0     GNI per capita, Atlas method (current US$)     NY.GNP.PCAP.CD  1960
# 1             GDP per capita (constant 2010 US$)     NY.GDP.PCAP.KD  1960
# 2             GNI per capita (constant 2010 US$)     NY.GNP.PCAP.KD  1960
# 3  GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD  1960
# 4                              GDP (current LCU)     NY.GDP.MKTP.CN  1960
#
#             GDP (%)
# 0                ..
# 1  537.461013064514
# 2                ..
# 3                ..
# 4        5651898400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3190 entries, 0 to 3189
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Series Name  3190 non-null   object
#  1   Series Code  3190 non-null   object
#  2   Year         3190 non-null   int32
#  3   GDP (%)      3190 non-null   object
# dtypes: int32(1), object(3)
# memory usage: 272.1+ KB

# %%
df.describe(include = "all")
# Out:
#                             Series Name     Series Code         Year GDP (%)
# count                              3190            3190  3190.000000    3190
# unique                               58              58          NaN    2411
# top     External debt stocks (% of GNI)  BN.KLT.PTXL.CD          NaN      ..
# freq                                 55              55          NaN     731
# mean                                NaN             NaN  1987.000000     NaN
# std                                 NaN             NaN    15.876997     NaN
# min                                 NaN             NaN  1960.000000     NaN
# 25%                                 NaN             NaN  1973.000000     NaN
# 50%                                 NaN             NaN  1987.000000     NaN
# 75%                                 NaN             NaN  2001.000000     NaN
# max                                 NaN             NaN  2014.000000     NaN

# %%
df.to_csv("D:\Open Classroom\Data Files\Kenya Data\Kenya_GDP.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\Kenya Data\Kenya_GDP.csv", index_col = "GDP (%)")
df.drop(columns = ["Unnamed: 0"], inplace = True)
df.head()
# Out:
#                                                     Series Name  \
# GDP (%)
# ..                   GNI per capita, Atlas method (current US$)
# 537.461013064514             GDP per capita (constant 2010 US$)
# ..                           GNI per capita (constant 2010 US$)
# ..                GNI per capita, PPP (current international $)
# 5651898400                                    GDP (current LCU)
#
#                         Series Code  Year
# GDP (%)
# ..                   NY.GNP.PCAP.CD  1960
# 537.461013064514     NY.GDP.PCAP.KD  1960
# ..                   NY.GNP.PCAP.KD  1960
# ..                NY.GNP.PCAP.PP.CD  1960
# 5651898400           NY.GDP.MKTP.CN  1960

# %%
df.shape
# Out:
# (3190, 3)

# %%
df = df.dropna(axis = "index", how = "any")
df.shape
# Out:
# (3190, 3)

# %%
df.head()
# Out:
#                                                     Series Name  \
# GDP (%)
# ..                   GNI per capita, Atlas method (current US$)
# 537.461013064514             GDP per capita (constant 2010 US$)
# ..                           GNI per capita (constant 2010 US$)
# ..                GNI per capita, PPP (current international $)
# 5651898400                                    GDP (current LCU)
#
#                         Series Code  Year
# GDP (%)
# ..                   NY.GNP.PCAP.CD  1960
# 537.461013064514     NY.GDP.PCAP.KD  1960
# ..                   NY.GNP.PCAP.KD  1960
# ..                NY.GNP.PCAP.PP.CD  1960
# 5651898400           NY.GDP.MKTP.CN  1960

# %%
df = df.reset_index()
df.head()
# Out:
#             GDP (%)                                    Series Name  \
# 0                ..     GNI per capita, Atlas method (current US$)
# 1  537.461013064514             GDP per capita (constant 2010 US$)
# 2                ..             GNI per capita (constant 2010 US$)
# 3                ..  GNI per capita, PPP (current international $)
# 4        5651898400                              GDP (current LCU)
#
#          Series Code  Year
# 0     NY.GNP.PCAP.CD  1960
# 1     NY.GDP.PCAP.KD  1960
# 2     NY.GNP.PCAP.KD  1960
# 3  NY.GNP.PCAP.PP.CD  1960
# 4     NY.GDP.MKTP.CN  1960

# %%
df["GDP (%)"].replace("..", 0, inplace = True)

# %%
df.head()
# Out:
#             GDP (%)                                    Series Name  \
# 0                 0     GNI per capita, Atlas method (current US$)
# 1  537.461013064514             GDP per capita (constant 2010 US$)
# 2                 0             GNI per capita (constant 2010 US$)
# 3                 0  GNI per capita, PPP (current international $)
# 4        5651898400                              GDP (current LCU)
#
#          Series Code  Year
# 0     NY.GNP.PCAP.CD  1960
# 1     NY.GDP.PCAP.KD  1960
# 2     NY.GNP.PCAP.KD  1960
# 3  NY.GNP.PCAP.PP.CD  1960
# 4     NY.GDP.MKTP.CN  1960

# %%
df.set_index(df["GDP (%)"], inplace = True)
df.to_csv("D:\Open Classroom\Data Files\Kenya Data\Org_Kenya_GDP.csv")

# %%
df = pd.read_csv("D:\Open Classroom\Data Files\Kenya Data\Org_Kenya_GDP.csv")
df.drop(columns = ["GDP (%).1"], inplace = True)
df.head()
# Out:
#         GDP (%)                                    Series Name  \
# 0  0.000000e+00     GNI per capita, Atlas method (current US$)
# 1  5.374610e+02             GDP per capita (constant 2010 US$)
# 2  0.000000e+00             GNI per capita (constant 2010 US$)
# 3  0.000000e+00  GNI per capita, PPP (current international $)
# 4  5.651898e+09                              GDP (current LCU)
#
#          Series Code  Year
# 0     NY.GNP.PCAP.CD  1960
# 1     NY.GDP.PCAP.KD  1960
# 2     NY.GNP.PCAP.KD  1960
# 3  NY.GNP.PCAP.PP.CD  1960
# 4     NY.GDP.MKTP.CN  1960

# %%
df.describe()
# Out:
#             GDP (%)         Year
# count  3.190000e+03  3190.000000
# mean   1.455724e+10  1987.000000
# std    1.998773e+11    15.876997
# min   -7.633760e+10  1960.000000
# 25%    0.000000e+00  1973.000000
# 50%    1.298398e+01  1987.000000
# 75%    1.099334e+02  2001.000000
# max    5.402647e+12  2014.000000

# %%
df.head()
# Out:
#         GDP (%)                                    Series Name  \
# 0  0.000000e+00     GNI per capita, Atlas method (current US$)
# 1  5.374610e+02             GDP per capita (constant 2010 US$)
# 2  0.000000e+00             GNI per capita (constant 2010 US$)
# 3  0.000000e+00  GNI per capita, PPP (current international $)
# 4  5.651898e+09                              GDP (current LCU)
#
#          Series Code  Year
# 0     NY.GNP.PCAP.CD  1960
# 1     NY.GDP.PCAP.KD  1960
# 2     NY.GNP.PCAP.KD  1960
# 3  NY.GNP.PCAP.PP.CD  1960
# 4     NY.GDP.MKTP.CN  1960

# %%
plt.plot(df["Year"], df["GDP (%)"], label = "Rate (%)")
plt.title("Gross Domestic Product Growth (%)")
plt.xlabel("Year")
plt.legend(loc = "best")
plt.show()

# %%
grpYear = (df["Year"] == 1960)
df[grpYear]
grp = df.groupby("Year")
grp["Series Name"].value_counts()
# Out:
# Year  Series Name
# 1960  Agricultural raw materials exports (% of merchandise exports)              1
#       Agriculture, forestry, and fishing, value added (% of GDP)                 1
#       Consumer price index (2010 = 100)                                          1
#       Current account balance (% of GDP)                                         1
#       Expense (% of GDP)                                                         1
#                                                                                 ..
# 2014  Service exports (BoP, current US$)                                         1
#       Total debt service (% of GNI)                                              1
#       Total debt service (% of exports of goods, services and primary income)    1
#       Total reserves (includes gold, current US$)                                1
#       Total reserves in months of imports                                        1
# ...

# %%
count = 0
for i in df["Year"].value_counts():
    count += 1
print(count)
# Out:
# 3190

# %%
year = df["Year"]
rate = df["GDP (%)"]

plt.scatter(year, rate, s = 100, c = year, cmap = "viridis")
cbar = plt.colorbar()
cbar.set_label("Year")
plt.show()
